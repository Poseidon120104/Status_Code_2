# %%
import google.generativeai as genai
from PIL import Image
import json

# Configure Gemini
genai.configure(api_key="AIzaSyCB53RM74IVZW6BWdZ7oDNR22p611l7AnI")

# Load model
model = genai.GenerativeModel("gemini-1.5-flash")

# Load prescription image
image = Image.open("/Users/anik/Desktop/sc2/ML/hard.jpg")

# Ask Gemini to output structured JSON
prompt = """
Extract the prescription details in JSON format with the following fields:
{
  "patient": string,
  "age": string,
  "symptoms": [string],
  "diagnosis": string,
  "medications": [
    {"name": string, "dose": string}
  ],
  "advice": [string]
}
Return only valid JSON.
"""

response = model.generate_content([prompt, image])

# Try parsing JSON
try:
    result = json.loads(response.text)
    print(json.dumps(result, indent=2))
except json.JSONDecodeError:
    print("Raw output (not strict JSON):")
    print(response.text)
# Out:
# Raw output (not strict JSON):
# ```json
# {
#   "patient": "ADRISH ROY",
#   "age": "21",
#   "symptoms": [
#     "ene from",
#     "stand",
#     "indumed"
#   ],
#   "diagnosis": null,
#   "medications": [
#     {
#       "name": "Tobetas",
#       "dose": null
#     },
#     {
#       "name": "Sensor oil",
#       "dose": null
#     },
#     {
#       "name": "Cap. K-Dox",
#       "dose": "Choo"
#     },
#     {
#       "name": "Mand's face wash",
#       "dose": null
#     }
#   ],
#   "advice": [
#     "R",
#     "spf 50",
#     "8m-11m"
#   ]
# }
# ```

# %%
import google.generativeai as genai
import json

genai.configure(api_key="AIzaSyBauan5eGHq8Gy-3mXXnXY_unp3crEn-WY")
model = genai.GenerativeModel("gemini-1.5-flash")

prompt = f"""
You are a medical assistant.  
I will provide you with a prescription in JSON format that contains patient details, symptoms, diagnosis, prescribed medications, and advice.  

Your tasks:  
1. Cross-check whether the prescribed medications are consistent with the listed symptoms and diagnosis.  
2. If you find any abnormalities, mismatches, or unclear medications, update or annotate them.  
3. Ensure each medication entry has both a name and a dose (fill in with "unspecified" if not mentioned).  
4. Keep the JSON structure the same, but add an extra field "notes" to each medication where you explain if it looks unusual, unnecessary, or correct.  
5. Return only valid JSON, nothing else.

Prescription JSON:
{json.dumps(response.text, indent=2)}
"""

response = model.generate_content(prompt)

try:
    result = json.loads(response.text)
    print(json.dumps(result, indent=2))
except json.JSONDecodeError:
    print("Raw output:")
    print(response.text)
# Out:
# Raw output:
# ```json
# {
#   "patient": "ADRISH ROY",
#   "age": "21",
#   "symptoms": [
#     "ene from",
#     "stand",
#     "indumed"
#   ],
#   "diagnosis": null,
#   "medications": [
#     {
#       "name": "Tobetas",
#       "dose": "unspecified",
#       "notes": "Unable to verify medication or appropriate dose.  Requires further clarification.  The symptoms provided are insufficient for assessment."
#     },
#     {
#       "name": "Sensor oil",
#       "dose": "unspecified",
#       "notes": "Unable to verify medication or appropriate dose.  Requires further clarification.  The symptoms provided are insufficient for assessment.  Potentially a topical treatment, but more information needed."
#     },
#     {
#       "name": "Cap. K-Dox",
#       "dose": "Choo",
#       "notes": "Dose 'Choo' is unclear and requires clarification.  Unable to verify medication or appropriate dose. The symptoms provided are insufficient for assessment."
#     },
#     {
# ...

# %%
print(response.text)
# Out:
# ```json
# {
#   "patient": "ADRISH ROY",
#   "age": "21",
#   "symptoms": [
#     "ene from",
#     "stand",
#     "indumed"
#   ],
#   "diagnosis": null,
#   "medications": [
#     {
#       "name": "Tobetas",
#       "dose": "unspecified",
#       "notes": "Unable to verify medication or appropriate dose.  Requires further clarification.  The symptoms provided are insufficient for assessment."
#     },
#     {
#       "name": "Sensor oil",
#       "dose": "unspecified",
#       "notes": "Unable to verify medication or appropriate dose.  Requires further clarification.  The symptoms provided are insufficient for assessment.  Potentially a topical treatment, but more information needed."
#     },
#     {
#       "name": "Cap. K-Dox",
#       "dose": "Choo",
#       "notes": "Dose 'Choo' is unclear and requires clarification.  Unable to verify medication or appropriate dose. The symptoms provided are insufficient for assessment."
#     },
#     {
#       "name": "Mand's face wash",
# ...

# %%
import json
import google.generativeai as genai

genai.configure(api_key=("AIzaSyBvOjpZhvYirYSB6XAWqZcuR2FTi6-vt3M"))
model = genai.GenerativeModel("gemini-1.5-flash")



prompt = f"""
You are a medical assistant AI.

Task:
I will provide a prescription in JSON format. The "medications" field may contain dosage information in different places:
- inside the "dose" field
- inside the "notes" field
- sometimes even appended to the "name" field (doctor shorthand in another line)

Your job:
1. Scan every medication entry completely (name, dose, notes).
2. Detect if any medical shorthand/abbreviation is used for dosage instructions.
3. Normalize the shorthand into clear, plain-language dosage instructions.
x. also note is any illegal name or shorthands are there try updating it to the closest reference given below
4. Put the **final corrected dosage only in the "dose" field**.
5. Keep all other fields intact (patient info, symptoms, advice, etc.).
6. If multiple dosage abbreviations appear across fields, merge them into one consistent plain-language instruction.
7. Do not invent new medicines or doses — only expand shorthands.

Reference abbreviations to expand:
- bdpc → twice daily after meals
- bdac → twice daily before meals
- odpc → once daily after meals
- tdpc → thrice daily after meals
- bid / b.i.d. → twice a day
- tid / t.i.d. → three times a day
- qid / q.i.d. → four times a day
- qd / q.d. → once a day
- qod / q.o.d. → every other day
- hs / qhs → at bedtime
- ac / a.c. → before meals
- pc / p.c. → after meals

Return only the updated JSON with the same structure.

Here’s the input JSON:
{json.dumps(response.text, indent=2)}
"""


response = model.generate_content(prompt)

try:
    result = json.loads(response.text)
    print(json.dumps(result, indent=2))
except json.JSONDecodeError:
    print("Raw output:")
    print(response.text)
# Out:
# Raw output:
# ```json
# {
#   "patient": "ADRISH ROY",
#   "age": "21",
#   "symptoms": [
#     "ene from",
#     "stand",
#     "indumed"
#   ],
#   "diagnosis": null,
#   "medications": [
#     {
#       "name": "Tobetas",
#       "dose": "unspecified",
#       "notes": "Unable to verify medication or appropriate dose.  Requires further clarification.  The symptoms provided are insufficient for assessment."
#     },
#     {
#       "name": "Sensor oil",
#       "dose": "unspecified",
#       "notes": "Unable to verify medication or appropriate dose.  Requires further clarification.  The symptoms provided are insufficient for assessment.  Potentially a topical treatment, but more information needed."
#     },
#     {
#       "name": "Cap. K-Dox",
#       "dose": "unspecified",
#       "notes": "Dose 'Choo' is unclear and requires clarification.  Unable to verify medication or appropriate dose. The symptoms provided are insufficient for assessment."
#     },
#     {
# ...
